# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df1 = pd.read_csv('IMDB_movie_reviews_details.csv')

# %%
df1['year'].unique()
# Out:
# array(['1994', '1972', '2020', '2008', '1974', '1957', '2003', '1993',
#        '2010', '1999', '2001', '1966', '2002', '1990', '1980', '1975',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2018', '2011', '2006', '2000', '1988', '1985',
#        '1968', '1960', '1942', '1936', '1931', '2017', '2016', 'I 2017',
#        '2012', '2009', '2007', '1984', '1981', '1979', '1963', '1964',
#        '1950', '1940', '2013', 'I 2020', '2005', '2004', '1992', '1987',
#        '1986', '1983', '1976', '1973', '1971', '1959', '1958', '1952',
#        '1948', '1944', '1941', '1927', '1921', '2015', '2021', '1996',
#        '1989', '1978', '1965', '1961', '1953', '1925', '1924', 'III 2016',
#        'I 2014', 'I 2015', 'I 2013', '1982', '1967', '1955', '1951',
#        '1949', '1939', '1937', '1934', '1930', '1928', '1926', '1920',
#        'I 2004', '1970', '1969', '1956', '1947', '1945', '1943',
# ...

# %%
df1.replace({'I 2017':'2017','I 2020':'2020','III 2016':'2016',
       'I 2014':'2014', 'I 2015':'2015', 'I 2013':'2013',
       'I 2004':'2004',
       'II 2016':'2016', 'I 2011':'2011', 'I 2001':'2001', 'I 2010':'2010', 'I 2008':'2008', 'I 2007':'2007',
             'I 1985':'1985', 'III 2018':'2018',
       'II 2015':'2015', 'I 2016':'2016', 'I 1995':'1955'}, inplace = True)

# %%
df1['year'].unique()
# Out:
# array(['1994', '1972', '2020', '2008', '1974', '1957', '2003', '1993',
#        '2010', '1999', '2001', '1966', '2002', '1990', '1980', '1975',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2018', '2011', '2006', '2000', '1988', '1985',
#        '1968', '1960', '1942', '1936', '1931', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1963', '1964', '1950',
#        '1940', '2013', '2005', '2004', '1992', '1987', '1986', '1983',
#        '1976', '1973', '1971', '1959', '1958', '1952', '1948', '1944',
#        '1941', '1927', '1921', '2015', '2021', '1996', '1989', '1978',
#        '1965', '1961', '1953', '1925', '1924', '1982', '1967', '1955',
#        '1951', '1949', '1939', '1937', '1934', '1930', '1928', '1926',
#        '1920', '1970', '1969', '1956', '1947', '1945', '1943', '1938',
#        '1935', '1933', '1932', '1922'], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   name        1000 non-null   object
#  2   year        1000 non-null   object
#  3   runtime     1000 non-null   int64
#  4   genre       1000 non-null   object
#  5   rating      1000 non-null   float64
#  6   metascore   841 non-null    float64
#  7   timeline    1000 non-null   object
#  8   votes       1000 non-null   object
#  9   gross       829 non-null    object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 78.2+ KB

# %%
df1.head()
# Out:
#    Unnamed: 0                      name  year  runtime                 genre  \
# 0           0  The Shawshank Redemption  1994      142                 Drama
# 1           1             The Godfather  1972      175          Crime, Drama
# 2           2           Soorarai Pottru  2020      153                 Drama
# 3           3           The Dark Knight  2008      152  Action, Crime, Drama
# 4           4    The Godfather: Part II  1974      202          Crime, Drama
#
#    rating  metascore                                           timeline  \
# 0     9.3       80.0  Two imprisoned men bond over a number of years...
# 1     9.2      100.0  An organized crime dynasty's aging patriarch t...
# 2     9.1        NaN  Nedumaaran Rajangam "Maara" sets out to make t...
# 3     9.0       84.0  When the menace known as the Joker wreaks havo...
# 4     9.0       90.0  The early life and career of Vito Corleone in ...
#
#        votes     gross
# 0  2,394,059   $28.34M
# ...

# %%
df1.drop(['timeline','Unnamed: 0'], axis = 1, inplace = True)

# %%
df1.dropna(inplace = True)

# %%
df1
# Out:
#                          name  year  runtime                         genre  \
# 0    The Shawshank Redemption  1994      142                         Drama
# 1               The Godfather  1972      175                  Crime, Drama
# 3             The Dark Knight  2008      152          Action, Crime, Drama
# 4      The Godfather: Part II  1974      202                  Crime, Drama
# 5                12 Angry Men  1957       96                  Crime, Drama
# ..                        ...   ...      ...                           ...
# 991            Kelly's Heroes  1970      144        Adventure, Comedy, War
# 993           The Jungle Book  1967       78  Animation, Adventure, Family
# 994        A Hard Day's Night  1964       87               Comedy, Musical
# 997                     Shane  1953      118                Drama, Western
# 998     From Here to Eternity  1953      118           Drama, Romance, War
#
#      rating  metascore      votes     gross
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 747 entries, 0 to 998
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       747 non-null    object
#  1   year       747 non-null    object
#  2   runtime    747 non-null    int64
#  3   genre      747 non-null    object
#  4   rating     747 non-null    float64
#  5   metascore  747 non-null    float64
#  6   votes      747 non-null    object
#  7   gross      747 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 52.5+ KB

# %%
df1.votes = df1.votes.apply(lambda x:x,(',',''))
#df1.votes = pd.to_numeric(df1.votes)

# %%
#Question 1
df1.rating.max()

# %%
#MOVIE WITH THE HIGHEST RATING IS THESHAWSHANK REDEMPTION
df1[df1.rating == 9.3]
# Out:
#                        name  year  runtime  genre  rating  metascore  \
# 0  The Shawshank Redemption  1994      142  Drama     9.3       80.0
#
#        votes    gross
# 0  2,394,059  $28.34M

# %%
#Question 2
df2 = df1.sort_values('rating', ascending = True)
df2
plt.plot(df2['name'], df2['rating'], 'green', marker = 'o')#line marker
plt.xlabel('Movie Name')
plt.ylabel('rating')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Question 3
df1[(df1['year'] >= '2008' ) & (df1['year'] <= '2019' )].info()
# 227 MOVIES WERE RELEASED BETWEEN 2008 AND 2019
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227 entries, 3 to 939
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       227 non-null    object
#  1   year       227 non-null    object
#  2   runtime    227 non-null    int64
#  3   genre      227 non-null    object
#  4   rating     227 non-null    float64
#  5   metascore  227 non-null    float64
#  6   votes      227 non-null    object
#  7   gross      227 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 16.0+ KB

# %%
#Question 4
df1
# Out:
#                          name  year  runtime                         genre  \
# 0    The Shawshank Redemption  1994      142                         Drama
# 1               The Godfather  1972      175                  Crime, Drama
# 3             The Dark Knight  2008      152          Action, Crime, Drama
# 4      The Godfather: Part II  1974      202                  Crime, Drama
# 5                12 Angry Men  1957       96                  Crime, Drama
# ..                        ...   ...      ...                           ...
# 991            Kelly's Heroes  1970      144        Adventure, Comedy, War
# 993           The Jungle Book  1967       78  Animation, Adventure, Family
# 994        A Hard Day's Night  1964       87               Comedy, Musical
# 997                     Shane  1953      118                Drama, Western
# 998     From Here to Eternity  1953      118           Drama, Romance, War
#
#      rating  metascore      votes     gross
# ...

# %%
df1['genre'].value_counts()
# Out:
# Drama                         67
# Comedy, Drama                 26
# Drama, Romance                26
# Crime, Drama, Thriller        25
# Action, Adventure, Sci-Fi     21
#                               ..
# Adventure, Thriller            1
# Animation, Comedy, Fantasy     1
# Animation, Sci-Fi              1
# Drama, Music, Mystery          1
# Adventure, Comedy, War         1
# Name: genre, Length: 175, dtype: int64

# %%
sns.barplot (x = df1['genre'].value_counts(), hue = df1['metascore'].value_counts(), data = df1)
plt.show()

# %%
df1[:10]
# Out:
#                                              name  year  runtime  \
# 0                        The Shawshank Redemption  1994      142
# 1                                   The Godfather  1972      175
# 3                                 The Dark Knight  2008      152
# 4                          The Godfather: Part II  1974      202
# 5                                    12 Angry Men  1957       96
# 6   The Lord of the Rings: The Return of the King  2003      201
# 7                                    Pulp Fiction  1994      154
# 8                                Schindler's List  1993      195
# 9                                       Inception  2010      148
# 10                                     Fight Club  1999      139
#
#                         genre  rating  metascore      votes     gross
# 0                       Drama     9.3       80.0  2,394,059   $28.34M
# 1                Crime, Drama     9.2      100.0  1,658,439  $134.97M
# ...

# %%
#question 5
df1[:10]
# Out:
#                                              name  year  runtime  \
# 0                        The Shawshank Redemption  1994      142
# 1                                   The Godfather  1972      175
# 3                                 The Dark Knight  2008      152
# 4                          The Godfather: Part II  1974      202
# 5                                    12 Angry Men  1957       96
# 6   The Lord of the Rings: The Return of the King  2003      201
# 7                                    Pulp Fiction  1994      154
# 8                                Schindler's List  1993      195
# 9                                       Inception  2010      148
# 10                                     Fight Club  1999      139
#
#                         genre  rating  metascore      votes     gross
# 0                       Drama     9.3       80.0  2,394,059   $28.34M
# 1                Crime, Drama     9.2      100.0  1,658,439  $134.97M
# ...

# %%
print(f' percentage of movies with 9+ ratings is {(5/747)*100} %')
# Out:
#  percentage of movies with 9+ ratings is 0.6693440428380187 %

# %%
#question 6
df2 = df1[(df1['year'] >= '2010' ) & (df1['year'] <= '2020' )]

# %%
df2.sort_values('year')
# Out:
#                                 name  year  runtime  \
# 9                          Inception  2010      148
# 231         How to Train Your Dragon  2010       98
# 354  Elite Squad 2: The Enemy Within  2010      115
# 355                The King's Speech  2010      118
# 361                  My Name Is Khan  2010      165
# ..                               ...   ...      ...
# 344                        Gully Boy  2019      154
# 195       Portrait of a Lady on Fire  2019      122
# 740                      Toy Story 4  2019      100
# 615                     The Irishman  2019      209
# 471                       Knives Out  2019      130
#
#                             genre  rating  metascore      votes     gross
# 9       Action, Adventure, Sci-Fi     8.8       74.0  2,113,984  $292.58M
# 231  Animation, Action, Adventure     8.1       75.0    678,716  $217.58M
# 354          Action, Crime, Drama     8.0       71.0     80,014    $0.10M
# ...

# %%
fig = plt.figure(figsize = (15,10))
rating = df2['year'].value_counts().plot.pie(autopct = '%1.2f%%')

# %%
#Question 7
df1
# Out:
#                          name  year  runtime                         genre  \
# 0    The Shawshank Redemption  1994      142                         Drama
# 1               The Godfather  1972      175                  Crime, Drama
# 3             The Dark Knight  2008      152          Action, Crime, Drama
# 4      The Godfather: Part II  1974      202                  Crime, Drama
# 5                12 Angry Men  1957       96                  Crime, Drama
# ..                        ...   ...      ...                           ...
# 991            Kelly's Heroes  1970      144        Adventure, Comedy, War
# 993           The Jungle Book  1967       78  Animation, Adventure, Family
# 994        A Hard Day's Night  1964       87               Comedy, Musical
# 997                     Shane  1953      118                Drama, Western
# 998     From Here to Eternity  1953      118           Drama, Romance, War
#
#      rating  metascore      votes     gross
# ...

# %%
print('''
1. Drama
2. Crime Drama
3. Drama
4. Action, crime Drama
5. Adventure, Action, drama
.....are the categories with the highest ratings''')
# Out:
# 1. Drama
# 2. Crime Drama
# 3. Drama
# 4. Action, crime Drama
# 5. Adventure, Action, drama
# .....are the categories with the highest ratings

# %%
#Question 8
plt.plot(df1['name'], df1['runtime'], 'green', marker = 'o')#line marker
plt.xlabel('Movie Name')
plt.ylabel('movie runtime')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
